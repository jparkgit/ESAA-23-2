# %% [markdown]
# <a href="https://colab.research.google.com/github/jparkgit/ESAA-23-2/blob/main/Week2_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
ax = plt.subplots()
ax = sns.histplot(tips['total_bill'])
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
scatter = plt.figure()
ax = scatter.add_subplot(1,1,1)
ax.scatter(tips['total_bill'], tips['tip'], s=15, alpha=0.5)
ax.set_title('Scatterplot of Total Bill vs Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x = tips['total_bill'],
    y = tips['tip'],
    s = tips['size']*10,# 점 size
    alpha = 0.5 # 점의 투명도
)
axes1.set_title('Total Bill vs Tip : Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
tips["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
ax = plt.subplots()
ax = sns.boxplot(x='day', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by days')
ax.set_xlabel('Days')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
#sns.stripplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x="day", y="total_bill", data=tips, hue = 'day', legend=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
fig, axs = plt.subplots(ncols=2)
fig.set_figwidth(12)
fig.set_figheight(5)
sns.stripplot(data=tips, x="total_bill", y="day", hue='sex',ax=axs[0])
sns.swarmplot(data=tips, x="total_bill", y="day", hue='sex',ax=axs[1])
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.stripplot(data=tips, x="total_bill", y="day", hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.swarmplot(data=tips, x="total_bill", y="day", hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
fig, axs = plt.subplots(ncols=2)
fig.suptitle('Histograms of tip value')
fig.set_figwidth(10)
fig.set_figheight(3)
ax1=sns.histplot(data=tips[tips['time']=='Lunch'], x="tip",ax=axs[0])
ax1.title.set_text('Lunch')
ax2=sns.histplot(data=tips[tips['time']=='Dinner'], x="tip",ax=axs[1])
ax2.title.set_text('Dinner')

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
fig, axs = plt.subplots(ncols=2)
fig.suptitle('Scatterplots of Tip vs Total Bill')
fig.set_figwidth(10)
fig.set_figheight(3)
ax1=sns.scatterplot(data=tips[tips['sex']=='Female'], x="total_bill", y='tip', hue = 'smoker', ax=axs[0], s=10)
ax1.title.set_text('Female')
ax2=sns.scatterplot(data=tips[tips['sex']=='Male'], x="total_bill", y="tip", hue = 'smoker', ax=axs[1], s=10)
ax2.title.set_text('Male')

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.

# %% [markdown]
# #### Draw a grouped violinplots of each day, with violins split by sex

# %%
# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=tips, x="day", y="total_bill", hue="sex",
               split=True, inner="quart", linewidth=1,)
#inner = Representation of the datapoints in the violin interior.
#     box: draw a miniature boxplot
#     quartiles: draw the quartiles of the distribution
#     point or stick: show each underlying datapoint
sns.despine(left=False) #Remove the top and right spines from plot(s).
